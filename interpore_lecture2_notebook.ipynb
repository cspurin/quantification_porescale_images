# %% [markdown]
# ### Packages that are useful for processing

# %%
#image processing 
import utils           #custom package to deal with 3D images 
import skimage
from skimage import data, img_as_float, img_as_ubyte, exposure
from skimage.restoration import denoise_nl_means
from skimage.segmentation import watershed
from skimage.feature import peak_local_max

#image visualization 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os
import tifffile as tif
import ipywidgets as widgets
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from skimage.color import label2rgb

#image quantification 
import numpy as np
import quantimpy
from quantimpy import minkowski as mk
from quantimpy import morphology as mp

# %% [markdown]
# ### Let's load in our data

# %%
dry_data       = skimage.io.imread("dry_scan_subvolume.tif")
wet_data       = skimage.io.imread("wet_scan_subvolume.tif")
segmented_data = skimage.io.imread("segmented_subvolume.tif")
overlay_image  = utils.sanity_check(dry_data[20, ...], segmented_data[20, ...], 0.2)

fig, axes = plt.subplots(2, 2, figsize=(10, 10))
axes[0, 0].imshow(dry_data[20, :, :], cmap='gray')
axes[0, 0].set_title('Dry Data')
axes[0, 1].imshow(wet_data[20, :, :], cmap='gray')
axes[0, 1].set_title('Wet Data')
axes[1, 0].imshow(segmented_data[20, :, :])
axes[1, 0].set_title('Segmented Data')
axes[1, 1].imshow(overlay_image)
axes[1, 1].set_title('Segmented Overlay')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Let's view our segmented data set in 3D

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
data = segmented_data[:40, :40, :40]
ax.voxels(data, alpha = 0.7)
plt.show()

#you can see the voxels in the image. We are zooming right in to make processing quick! 3D visualization is limited by your graphics card and computer memory. 
#Visualization can take a long time dependent on your machine
#Some images you'll see in papers will have had smoothing corrections applied to them

# %% [markdown]
# ### Volume calculation

# %%
# volume is the easiest calculation to make. You sum up the voxels == 1 (pore = 1 and rock grains = 0) and divide by the total number of voxels 
pore_voxels = np.sum(segmented_data==1)
rock_voxels = np.sum(segmented_data==0)
porosity_total = pore_voxels / (pore_voxels + rock_voxels)
print('The average porosity for the subvolume is', porosity_total)

#but it is also useful to look at the slice averaged porosity and see how that changes 
slice_averaged_porosity    = [np.sum(image==1)/(np.sum(image==1)+np.sum(image==0))  for image in segmented_data]  #takes each z slice and works out the average porosity 
plt.plot(slice_averaged_porosity)
plt.ylabel('Porosity')
plt.xlabel('Slice number')
plt.ylim(0, 0.3)
plt.show()

#you can also convert slice number to an actual length, if you know the size of a voxel 
voxel_size = 0.01 #mm
voxel_list = [i * voxel_size for i in range(len(slice_averaged_porosity))] #these functions are called list comprehensions
plt.plot(voxel_list, slice_averaged_porosity)
plt.ylabel('Porosity')
plt.xlabel('Distance from starting point (mm)')
plt.ylim(0, 0.3)
plt.show()
# Out:
# The average porosity for the subvolume is 0.2079805

# %% [markdown]
# ### Surface area calculation

# %%
def surface_area_calculation(data, smoothing):
    #to calculate the surface area, we first need to create a surface mesh
    if smoothing == 'None':
        verts, faces, normals, values = skimage.measure.marching_cubes(data, level = None)
    else: 
        verts, faces, normals, values = skimage.measure.marching_cubes(data, level = smoothing)
    

    # Create a 3D plot to visualize the mesh 
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Plot the mesh vertices
    ax.scatter(verts[:, 0], verts[:, 1], verts[:, 2], c='b', marker='.')
    # Plot the mesh faces
    mesh = Poly3DCollection(verts[faces], alpha=0.2)
    ax.add_collection3d(mesh)
    plt.show()

    #from the mesh, we can calculate the surface area 
    surface_area = skimage.measure.mesh_surface_area(verts, faces)
    print('The surface area is {:.2f} voxels\u00B2'.format(surface_area))
    return surface_area

#NB, the surface area will be dependent on the smoothing chosen 
# level float, optional: Contour value to search for isosurfaces in volume. If not given or None, the average of the min and max of vol is used.
surface_area_1 = surface_area_calculation(data, 'None')
surface_area_2 = surface_area_calculation(data, 0)  #'blockiest' case

print('Smoothing can havilty influence the surface area calculated. In this case, the variation was {:.2f} %'.format(100*(surface_area_2- surface_area_1) / (0.5*(surface_area_2 + surface_area_1))))
# Out:
# The surface area is 14033.56 voxels²
# The surface area is 16261.36 voxels²
# Smoothing can havilty influence the surface area calculated. In this case, the variation was 14.71 %

# %% [markdown]
# ### Mean curvature calculation

# %%
# this is where things get trickier! 
# 3D curvature measurements are not trivial to calculate and there are many methods to calcualte the curvature for a 3D surface 
# we will use the module QuantImpy to help us calculate the curvature: https://doi.org/10.1016/j.softx.2021.100823

#The Euler characteristic is heavily influenced by image resolution, so we will remove small spots with an erosion 
erosion_map = mp.erode_map(segmented_data)

#Calculate the functionals by dilated the eroded data
dist, m0, m1, m2, m3 = mk.functions_open(segmented_data)

fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # Adjust the figsize as needed
axs[0].imshow(segmented_data[10, :, :], cmap='viridis')  
axs[0].set_title('Segmented Data')
axs[1].imshow(erosion_map[10, :, :], cmap='viridis')  
axs[1].set_title('Erosion Map')
plt.show()


mean_curvature = 2*np.pi**2 *m2 
print('The integral mean curvature is:', int(mean_curvature[0]), ', units = [1/voxels]')
# Out:
# The integral mean curvature is: 386665 , units = [1/voxels]

# %% [markdown]
# ### Euler characteristic calculation

# %%
# using skimage 
Euler = skimage.measure.euler_number(segmented_data, connectivity = 3)
print('The euler characteristic calculated from the skimage package:', Euler)

# using quantimpy 
euler_quantimpy = int(np.sum(m3)*4*np.pi/3)
print('The euler characteristic calculated from the skimage package:', euler_quantimpy)

print('The difference between packages is:', int(100*(euler_quantimpy - Euler) / (0.5*(euler_quantimpy+Euler))) , '%')

# in the skimage package, we can change the connectivity needed for voxels to be taken as connected 
#A large relative difference between results for different connectivities suggests that the image resolution (with respect to the size of objects and holes) is too low.

Euler2 = skimage.measure.euler_number(segmented_data, connectivity = 1)
print('The euler characteristic calculated from the skimage package, with lower connectivity', Euler2)
# Out:
# The euler characteristic calculated from the skimage package: -11532
# The euler characteristic calculated from the skimage package: -11325
# The difference between packages is: -1 %
# The euler characteristic calculated from the skimage package, with lower connectivity -11452

# %% [markdown]
# ### Looking at the connectivity of the pore space

# %%
labeled_image = skimage.measure.label(data, connectivity =3)
num_objects   = np.max(labeled_image)

#plot the labelled image 
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
for i in range(1, num_objects): 
    filled_blob = skimage.morphology.remove_small_objects(labeled_image==i)
    ax.voxels(filled_blob)
plt.show()


# in reality, the pore space is all connected. In this case the disconnected parts are just close to the edges. 
# otherwise disconnected pore space is a signal that your image resolution is limited.

# %% [markdown]
# ### Interlude to compare quantimpy with skimage for other variables

# %%
# comparison of skimage to quantimpy for volume 
print('The volume from skimage is {:.2f} voxels\u00B3'.format(pore_voxels))
print('The volume from quantimpy is {:.2f} voxels\u00B3'.format(int(m0)))
print('The difference in methods (from the erosion) is', 100*(pore_voxels - m0) / (0.5*(pore_voxels + m0)), '%')

#comparison of skimage to quantimpy for surface area (as surface area dependent on mesh)

verts, faces, normals, values = skimage.measure.marching_cubes(segmented_data, level = None)
surface_area = skimage.measure.mesh_surface_area(verts, faces)
print('The surface area from skimage is {:.2f} voxels\u00B2'.format(surface_area))

surface_area_quantimpy = int(8*m1)
print('The surface area from quantimpy is {:.2f} voxels\u00B2'.format(surface_area_quantimpy))


print('The difference in methods is', int(100*(surface_area - surface_area_quantimpy) / (0.5*(surface_area + surface_area_quantimpy))), '%')
# Out:
# The volume from skimage is 1663844.00 voxels³
# The volume from quantimpy is 1639356.00 voxels³
# The difference in methods (from the erosion) is [1.48268346] %
# The surface area from skimage is 1884927.62 voxels²
# The surface area from quantimpy is 1651276.00 voxels²
# The difference in methods is 13 %

# %% [markdown]
# ### Sphere generation

# %%
# Create a 3D figure
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Create a sphere
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 1.0 * np.outer(np.cos(u), np.sin(v))
y = 1.0 * np.outer(np.sin(u), np.sin(v))
z = 1.0 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the sphere
ax.plot_surface(x, y, z, color='b', alpha=0.2, rstride=10, cstride=10, zorder=0, edgecolor='k')

# Set axis labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_box_aspect([1, 1, 1])  # [x, y, z] ratios

radius = 1.0
# Plot arcs of curvature
u_arc = np.linspace(0, np.pi , 100)  # Angle for the arc (0 to 90 degrees)
x_arc = radius * np.cos(u_arc)
y_arc = radius * np.sin(u_arc)
z_arc = np.sqrt(abs(radius**2 - x_arc**2 - y_arc**2)) 

# Plot arcs of curvature in all three dimensions
ax.plot(x_arc, z_arc, y_arc, color='r', linewidth=4, zorder=1)
ax.plot(x_arc, z_arc, -y_arc, color='r', linewidth=4, zorder=1)
ax.plot(-y_arc, x_arc, z_arc, color='g', linewidth=4, zorder=1)
ax.plot(y_arc, x_arc, z_arc, color='g', linewidth=4, zorder=1)


# Show the plot
plt.show()

# %% [markdown]
# ### Maximum ball

# %%
from skimage.color import rgb2gray
from matplotlib.patches import Circle
import cv2

# Load the first image
kitty1 = skimage.io.imread("jackjack.png")
gray_kitty1 = rgb2gray(kitty1[:, :, :3])
binary_kitty1 = skimage.morphology.remove_small_objects((gray_kitty1 > 0)==0, min_size=10)


# Load the second image
kitty2 = skimage.io.imread("voidkitty.png")
gray_kitty2   = rgb2gray(kitty2[:, :, :3])
binary_kitty2 = skimage.morphology.remove_small_objects((gray_kitty2 > 0)==0, min_size=10)

#distance maps
distance_map_kitty1 = mp.erode_map(binary_kitty1==0)
distance_map_kitty2 = mp.erode_map(binary_kitty2==0)

#thing the maximum inscribed circle 
_, max_val1, _, centre1 = cv2.minMaxLoc(distance_map_kitty1)
_, max_val2, _, centre2 = cv2.minMaxLoc(distance_map_kitty2)


fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes[0, 0].imshow(kitty1)
axes[0, 0].set_title("Kitty 1")

axes[0, 1].imshow(binary_kitty1 == 0, cmap='gray')
axes[0, 1].set_title("Binary Kitty 1")


axes[1, 0].imshow(distance_map_kitty1, cmap='gray')
axes[1, 0].set_title("Distance Map Kitty 1")

axes[1, 1].imshow(kitty1)
axes[1, 1].set_title("Max Inscribe Circle Kitty 1")
circle1 = Circle((centre1[0], centre1[1]), max_val1, fill=False, linestyle='--', linewidth = 2, color='r')
axes[1, 1].add_patch(circle1)


fig2, axes2 = plt.subplots(2, 2, figsize=(12, 8))
axes2[0, 0].imshow(kitty2)
axes2[0, 0].set_title("Kitty 2")

axes2[0, 1].imshow(binary_kitty2 == 0, cmap='gray')
axes2[0, 1].set_title("Binary Kitty 2")

axes2[1, 0].imshow(distance_map_kitty2, cmap='gray')
axes2[1, 0].set_title("Distance Map Kitty 2")

axes2[1, 1].imshow(kitty2)
axes2[1, 1].set_title("Max Inscribe Circle Kitty 2")
circle2 = Circle((centre2[0], centre2[1]), max_val2, fill=False, linestyle='--', linewidth = 2, color='r')
axes2[1, 1].add_patch(circle2)


print("The radius of the maximum inscribed sphere for Jackjack is:", max_val1)

print("The radius of the maximum inscribed sphere for the Void is:", max_val2)
# Out:
# The radius of the maximum inscribed sphere for Jackjack is: 52.0
# The radius of the maximum inscribed sphere for the Void is: 68.0
